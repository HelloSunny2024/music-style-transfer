# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

class GenreClassifier(nn.Module):
    def __init__(self, input_channels=80, ndf=64, num_classes=2):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv1d(input_channels, ndf, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv1d(ndf, ndf * 2, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm1d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv1d(ndf * 2, ndf * 4, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm1d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),

            nn.AdaptiveAvgPool1d(1),
        )
        self.fc = nn.Linear(ndf * 4, num_classes)

    def forward(self, x):
        x = self.model(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

# 分类器加载函数
def load_model(model_path, num_classes, device):
    model = GenreClassifier(input_channels=80, num_classes=num_classes)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    return model

# 加载 .npy 的 mel 特征
def load_mel_npy(file_path, target_time_steps=2580):
    mel = np.load(file_path)
    mel = torch.tensor(mel).float()

    # 去除额外的维度
    mel = mel.squeeze(0)  # 将 [1, 1, 80, 2580] 转换为 [1, 80, 2580]
    mel = mel.squeeze(0)  # 将 [1, 80, 2580] 转换为 [80, 2580]

    # 如果时间步长不足，填充；如果太长，裁剪
    if mel.shape[1] < target_time_steps:
        mel = F.pad(mel, (0, target_time_steps - mel.shape[1]))
    elif mel.shape[1] > target_time_steps:
        mel = mel[:, :target_time_steps]

    return mel.unsqueeze(0)  # [1, 80, T] (添加 batch 维度)

# 遍历评估 .npy 文件夹
def evaluate_mel_folder(folder_path, model, label_map, expected_label_id, device):
    files = [f for f in os.listdir(folder_path) if f.endswith(".npy")]
    correct = 0
    total = len(files)

    # 遍历所有文件，逐个进行评估
    for file_name in files:
        mel = load_mel_npy(os.path.join(folder_path, file_name)).to(device)
        print(f"Evaluating file: {file_name}, Mel shape: {mel.shape}")

        with torch.no_grad():
            output = model(mel)
            pred = output.argmax(dim=1).item()

        # 打印每个文件的预测结果
        predicted_label = label_map[pred]
        print(f"Prediction: {predicted_label} (Expected: {label_map[expected_label_id]})")

        if pred == expected_label_id:
            correct += 1

    # 打印最终的准确率结果
    acc = correct / total if total > 0 else 0.0
    print(f"Evaluation complete. Total: {total} samples, Accuracy: {acc:.4f} ({label_map[expected_label_id]})")

    return acc

if __name__ == "__main__":
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    label_map = {0: "Pop", 1: "Rock"}
    inv_label_map = {v: k for k, v in label_map.items()}

    # 加载模型
    model_path = "best_genre_classifier.pth"
    model = load_model(model_path, num_classes=2, device=device)

    # 指定转换后的 .npy 目录
    converted_mel_dir = "/home/quincy/DATA/music/converted_features"
    target_label = "Rock"

    # 评估
    evaluate_mel_folder(
        folder_path=converted_mel_dir,
        model=model,
        label_map=label_map,
        expected_label_id=inv_label_map[target_label],
        device=device
    )
# Out:
# /tmp/ipykernel_886987/1857093206.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Evaluating file: 027802.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 048454.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 122500.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 113808.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 090587.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 126400.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 051267.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 035549.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 149078.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 127913.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 148606.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 011200.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 027797.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 113935.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 141179.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 127203.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 119193.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 019412.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 094632.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 131449.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 148585.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 144940.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 127298.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 085311.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 124481.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 067010.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 064006.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 029245.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 126401.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 018146.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 127279.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 122499.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 127300.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 032760.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 061589.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 012654.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 091161.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 046846.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 057435.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 055437.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 043773.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 109957.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 075314.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 055290.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 055285.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 085428.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 057078.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 138064.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 042914.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 134388.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 018145.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 131453.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 132791.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 058166.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 019074.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 122504.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 069747.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 069188.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 011261.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 019689.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 021657.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 045335.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 129056.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 026754.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 036618.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 085957.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 091162.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 032333.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 124484.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 051263.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 120112.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 138069.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 012527.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 067365.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 068355.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 047835.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 039666.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 079741.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 130372.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 144942.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 054033.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 039530.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 012188.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Pop (Expected: Rock)
# Evaluating file: 034511.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 132788.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 148586.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 013197.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 058161.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 068353.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 135338.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 093944.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 139043.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 090589.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 085593.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 013378.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 127268.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 066646.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 130265.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 041568.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluating file: 085956.wav_converted.npy, Mel shape: torch.Size([1, 80, 2580])
# Prediction: Rock (Expected: Rock)
# Evaluation complete. Total: 100 samples, Accuracy: 0.9100 (Rock)
